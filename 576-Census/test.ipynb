# %%
import json
from utils import load_datasets, load_target
import models

# %%
config = json.load(open('./config/default.json'))
# X_train, X_test = load_datasets(["Age", "AgeSplit", "EducationNum"])
X_train, X_test = load_datasets(config['features'])
y_train = load_target('Y')

# %%
y_train
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 10195    0
# 10196    0
# 10197    0
# 10198    0
# 10199    0
# Name: Y, Length: 10200, dtype: int64

# %%
X_train
# Out:
#        age age-split  education-num  fnlwgt  sex  workclass-?  \
# 0       22         3             12  132618    0            0
# 1       22         3              9  132655    1            0
# 2       23         4              8  132674    0            1
# 3       36         7             13  132642    1            0
# 4       49         8             13  132646    1            0
# ...    ...       ...            ...     ...  ...          ...
# 10195   31         6              9  132650    0            0
# 10196   36         7              9  132590    1            0
# 10197   36         7             13  132498    1            0
# 10198   17         1              9  132614    0            0
# 10199   36         7              4  132691    1            1
#
#        workclass-Federal-gov  workclass-Local-gov  workclass-Private  \
# 0                          0                    0                  1
# 1                          0                    0                  1
# ...

# %%
X_test
# Out:
#       age age-split  education-num  fnlwgt  sex  workclass-?  \
# 0      30         6             12  132646    1            0
# 1      30         6              4  132626    0            0
# 2      36         7              8  132505    1            0
# 3      23         4              9  132610    0            0
# 4      36         7              9  132468    1            0
# ...   ...       ...            ...     ...  ...          ...
# 6795   31         6              9  132530    0            0
# 6796   31         6              6  132634    1            0
# 6797   31         6             13  132598    1            0
# 6798   23         4              8  132573    0            0
# 6799   23         4              9  132633    0            1
#
#       workclass-Federal-gov  workclass-Local-gov  workclass-Private  \
# 0                         0                    0                  1
# 1                         0                    0                  1
# ...

# %%
X_train
# Out:
#        age age-split  education-num  fnlwgt  sex  workclass-?  \
# 0       22         3             12  132618    0            0
# 1       22         3              9  132655    1            0
# 2       23         4              8  132674    0            1
# 3       36         7             13  132642    1            0
# 4       49         8             13  132646    1            0
# ...    ...       ...            ...     ...  ...          ...
# 10195   31         6              9  132650    0            0
# 10196   36         7              9  132590    1            0
# 10197   36         7             13  132498    1            0
# 10198   17         1              9  132614    0            0
# 10199   36         7              4  132691    1            1
#
#        workclass-Federal-gov  workclass-Local-gov  workclass-Private  \
# 0                          0                    0                  1
# 1                          0                    0                  1
# ...

# %%
from sklearn.model_selection import train_test_split
model = models.Lgbm(config['model_params']['Lgbm'])
model.fit(X_train, y_train)

# %%
f

# %%
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yutahirai/Desktop/Github/Signate/576-Census/test.ipynb Cell 1' in <module>
# ----> <a href='vscode-notebook-cell:/Users/yutahirai/Desktop/Github/Signate/576-Census/test.ipynb#ch0000000?line=0'>1</a> X_train
#
# NameError: name 'X_train' is not defined

# %%
model.predict(X_test)

# %%
from models.evaluation import cross_validation_score

cv_score = cross_validation_score(model, X_train, y_train)

# %%
print(cv_score)

# %%
from models.evaluation import cross_validation_score
model = models.RandomForest(config["model_params"]["RandomForest"])
cv_score = cross_validation_score(model, X_train, y_train)

# %%
print(cv_score)

# %%
X_train

# %%
lgbm = models.Lgbm(config["model_params"]["Lgbm"])
rf = models.RandomForest(config["model_params"]["RandomForest"])

model_list = [lgbm, rf]

# %%
from models.evaluation import stacking

y_oof, y_pred = stucking(model_list, X_train, y_train, X_test, 2)

# %%
y_oof

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train, (y_oof>0.5).astype(int)))

# %%
from models.tuning import beyesian_optimization
lgbm = models.Lgbm(config["model_params"]["Lgbm"])
beyesian_optimization(lgbm, X_train, y_train, {
    'objective': 'binary',
    'max_bin': [32, 255],
    'learning_rate': [0.001, 0.1],
    'num_leaves': [32, 128]
})

# %%
lgbm
